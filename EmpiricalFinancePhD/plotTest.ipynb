# %%
using PyPlot

# %%
#run this, get deprecation warnings and then you don't see them in the restof the notebook
figure()                        
    plot(1:10,cos(1:10))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001A038860>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x000000001C1F0D68>

# %%
T = 100
x = 1:T
y1 = cumsum(randn(T,2))

figure()
ha = plot(x,y1[:,1],x,y1[:,2])
  xlim(minimum(x),maximum(x))
  ylim(-5,5)
  title("Return vs lagged return, kernel regression")
  xlabel("Lagged return")
  ylabel("Return")
leg = legend(["A";"B"])
show()


#println("done")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x000000001A066668>)
